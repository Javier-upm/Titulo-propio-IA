# %% [markdown]
# ## Python básico (Sesión 1) · Cuaderno interactivo
#
# Este cuaderno está pensado para que completes los bloques `# TODO` y ejecutes los **tests** (que están en `test1.py`).
#
# ### Flujo de trabajo
# 1. Abre el cuaderno en Colab.
# 2. **Archivo → Guardar una copia en Drive**
# 3. Ejecuta la celda **Setup** (descarga el repo y carga `test1.py`).
# 4. Completa cada ejercicio y ejecuta su celda de tests.
#
# > Nota: si reinicias el runtime, vuelve a ejecutar **Setup**.

# %% [markdown]
# ### Setup (ejecuta esta celda una vez)
# Esta celda descarga el repositorio del curso y hace importable `test1.py`.

# %%
# @title Setup (ejecuta 1 vez)
import os, sys

REPO_URL = "https://github.com/Javier-upm/Titulo-propio-IA"
REPO_DIR = "/content/Titulo-propio-IA"
SESSION_DIR = "sesion_1"   # carpeta donde están Sesion_1_basicas_1.ipynb y test1.py

if not os.path.exists(REPO_DIR):
    # !git clone --depth 1 "{REPO_URL}" "{REPO_DIR}"
else:
    print("Repo ya presente:", REPO_DIR)

tests_path = os.path.join(REPO_DIR, SESSION_DIR)
if tests_path not in sys.path:
    sys.path.insert(0, tests_path)

print("Ruta de sesión:", tests_path)
print("Contenido:", os.listdir(tests_path))

import test1
print("✅ test1.py importado correctamente")

# %% [markdown]
# ### Variables
# Python infiere tipos. Practicamos asignación y operaciones básicas.

# %%
import math  # lo usaremos más adelante

# Ejemplo
entero = 8
texto = "hola"
print(entero, type(entero))
print(texto, type(texto))
print(texto.capitalize())

# %% [markdown]
# #### Ejercicio 1
# 1) Define `a = 8` y `b = 'hola'`.
# 2) Crea `b_cap` con `b` capitalizada.
# 3) Crea `suma` con `a + 10`.
# 4) Imprime `b_cap` y `suma`.

# %%
# TODO
a = None
b = None
b_cap = None
suma = None

# TODO: imprime

# %%
# @title Tests Ejercicio 1 (no modificar)
from test1 import check_ej1
try:
    check_ej1(a, b, b_cap, suma)
    print("✅ Ejercicio 1 correcto")
except Exception as e:
    print("❌", e)

# %% [markdown]
# ### Variables compuestas
# Listas y diccionarios: indexado, slicing y acceso por clave.

# %%
# Ejemplo: listas
lista = [1, 2, 3, 4, 5]
print("lista:", lista)
print("slice [1:3]:", lista[1:3])

# Ejemplo: diccionarios
dicc = {"pi": 3.14159265, "e": 2.71828182, "aureo": 1.6180}
print("pi:", dicc["pi"])

# %% [markdown]
# #### Ejercicio 2
# Dada la lista `lista`, crea:
# - `sublista` con los elementos de índice 1 y 2
# - `ultimo` con el último elemento
# - `reversa` con la lista invertida (puedes usar slicing)
#
# Imprime las tres variables.

# %%
lista = [1, 2, 3, 4, 5]

# TODO
sublista = None
ultimo = None
reversa = None

# TODO: imprime

# %%
# @title Tests Ejercicio 2 (no modificar)
from test1 import check_ej2
try:
    check_ej2(sublista, ultimo, reversa, lista)
    print("✅ Ejercicio 2 correcto")
except Exception as e:
    print("❌", e)

# %% [markdown]
# #### Ejercicio 3
# Copia de listas: diferencia entre referencia y copia.
#
# 1) Crea `lista` como `[1,2,3]`.
# 2) Crea `lista_copia` como una **copia independiente**.
# 3) Modifica `lista[0] = 999`.
#
# Queremos que `lista_copia` NO cambie.

# %%
# TODO
lista = None
lista_copia = None

# TODO: modifica lista[0]

# %%
# @title Tests Ejercicio 3 (no modificar)
from test1 import check_ej3
try:
    check_ej3(lista, lista_copia)
    print("✅ Ejercicio 3 correcto")
except Exception as e:
    print("❌", e)

# %% [markdown]
# #### Ejercicio 4
# Dado el diccionario `dicc`, crea:
# - `pi_val` con el valor de `pi`
# - `claves` con una lista de claves ordenadas alfabéticamente
#
# Imprime ambas.

# %%
dicc = {"pi": 3.14159265, "e": 2.71828182, "aureo": 1.6180}

# TODO
pi_val = None
claves = None

# TODO: imprime

# %%
# @title Tests Ejercicio 4 (no modificar)
from test1 import check_ej4
try:
    check_ej4(pi_val, claves, dicc)
    print("✅ Ejercicio 4 correcto")
except Exception as e:
    print("❌", e)

# %% [markdown]
# ### Control de flujo: bucles y condicionales

# %%
# Ejemplo: bucle for
for i in range(5):
    if i % 2 == 0:
        print(i, "es par")
    else:
        print(i, "es impar")

# %% [markdown]
# #### Ejercicio 5
# Define `n = 45`. Calcula `suma_multiplos` como la suma de los números entre 0 y `n` (incluido) que sean múltiplos de 3.
#
# Imprime `suma_multiplos`.

# %%
n = 45

# TODO
suma_multiplos = None

# TODO: imprime

# %%
# @title Tests Ejercicio 5 (no modificar)
from test1 import check_ej5
try:
    check_ej5(n, suma_multiplos)
    print("✅ Ejercicio 5 correcto")
except Exception as e:
    print("❌", e)

# %% [markdown]
# ### Funciones
# Las funciones encapsulan lógica y se reutilizan.

# %%
# Ejemplo
def cuadrado(x):
    return x * x

print(cuadrado(3))

# %% [markdown]
# #### Ejercicio 6
# Implementa `funcion(x)` que devuelva la siguiente expresión:
#
# $ f(x) = \sqrt{x} + x^2 $
#
# - Si `x` es negativo, devuelve `None`.
#
# Prueba tu función con `x=4`.

# %%
import math

# TODO
def funcion(x):
    pass

print(funcion(4))

# %%
# @title Tests Ejercicio 6 (no modificar)
from test1 import check_ej6
try:
    check_ej6(funcion)
    print("✅ Ejercicio 6 correcto")
except Exception as e:
    print("❌", e)

# %% [markdown]
# #### Ejercicio 7
# Implementa `primo(n)` que devuelva:
#
# - `True` si `n` es primo.
# - `False` si `n` no es primo.
#
# Recuerda que 1 no es primo.

# %%
# TODO
def primo(n):
    pass

# %%
# @title Tests Ejercicio 7 (no modificar)
from test1 import check_ej7
try:
    check_ej7(primo)
    print("✅ Ejercicio 7 correcto")
except Exception as e:
    print("❌", e)
